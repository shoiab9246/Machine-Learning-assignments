# %%
import matplotlib.pyplot as plt
# %matplotlib inline

k_range = range(1, 31) ## number of nearest neighbors
k_acc_scores = [0.7263352723426757, 0.7150713907985192, 0.7314119513484929, 0.7296932839767318, 0.7328133262823903, 
              0.7313061872025384, 0.7475409836065574, 0.7507667900581703, 0.762083553675304, 0.770719196192489, 
              0.7524590163934426, 0.7590428344791116, 0.7557905869910101, 0.7590957165520889, 0.7623215230037017, 
              0.7589899524061343, 0.7525383395029085, 0.7574034902168164, 0.7475674246430459, 0.7622421998942358, 
              0.749206768905341, 0.7557377049180328, 0.7573770491803279, 0.7541248016922264, 0.7540983606557377, 
              0.7524061343204653, 0.757297726070862, 0.7638551031200423, 0.7574563722897938, 0.7556848228450554]
# plot the value of K for KNN (x-axis) versus the cross-validated accuracy (y-axis)
# plt.plot(x_axis, y_axis)
plt.plot(k_range, k_acc_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-validated accuracy')
plt.title("Pima Diabetes classification\nCrossValidation accuracy on KNN number of neighbors")
plt.grid()
